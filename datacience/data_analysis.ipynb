# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather=pd.read_csv("weather.csv",parse_dates=["Date.Full"],dayfirst=True)

# %% [markdown]
# ## data.gov.in we get data from here
# ## kagle : we get more data from it
# ## data.word :we get data from here and we can use it by signing in
# # ctrl+d for bookmark
# ## when date is givne we can do time series analysis :weekly,monthly

# %%
## understanding the data
weather.head()# first five records
# Out:
#    Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00 2016-01-03           1             3       2016
# 1                0.00 2016-01-03           1             3       2016
# 2                0.16 2016-01-03           1             3       2016
# 3                0.00 2016-01-03           1             3       2016
# 4                0.01 2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %%
weather.tail()#last five
# Out:
#        Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 16738                0.08 2017-01-01           1             1       2017
# 16739                0.00 2017-01-01           1             1       2017
# 16740                0.00 2017-01-01           1             1       2017
# 16741                0.06 2017-01-01           1             1       2017
# 16742                0.10 2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# 16738       Casper          CPR       Casper, WY       Wyoming
# 16739     Cheyenne          CYS     Cheyenne, WY       Wyoming
# 16740       Lander          LND       Lander, WY       Wyoming
# 16741      Rawlins          RWL      Rawlins, WY       Wyoming
# 16742     Sheridan          SHR     Sheridan, WY       Wyoming
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 16738                         23                         32
# ...

# %%
weather.head(10) #first 10 records
# Out:
#    Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00 2016-01-03           1             3       2016
# 1                0.00 2016-01-03           1             3       2016
# 2                0.16 2016-01-03           1             3       2016
# 3                0.00 2016-01-03           1             3       2016
# 4                0.01 2016-01-03           1             3       2016
# 5                0.09 2016-01-03           1             3       2016
# 6                0.05 2016-01-03           1             3       2016
# 7                0.15 2016-01-03           1             3       2016
# 8                0.60 2016-01-03           1             3       2016
# 9                2.15 2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# ...

# %%
weather.info()  ## by default if the data type is not unerstandable then the dt will be object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  datetime64[ns]
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %%
weather.describe()
# Out:
#        Data.Precipitation    Date.Month  Date.Week of     Date.Year  \
# count        16743.000000  16743.000000  16743.000000  16743.000000
# mean             0.579090      6.343128     15.650242   2016.018933
# std              0.988057      3.490723      8.923425      0.136294
# min              0.000000      1.000000      1.000000   2016.000000
# 25%              0.000000      3.000000      8.000000   2016.000000
# 50%              0.190000      6.000000     16.000000   2016.000000
# 75%              0.750000      9.000000     24.000000   2016.000000
# max             20.890000     12.000000     31.000000   2017.000000
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# ...

# %%
weather.describe(include='object')
# Out:
#        Station.City Station.Code Station.Location Station.State
# count         16743        16743            16743         16743
# unique          307          318              318            53
# top         Norfolk          BHM   Birmingham, AL        Alaska
# freq            106           53               53          1719

# %%
print(weather.columns.tolist())
# Out:
# ['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of', 'Date.Year', 'Station.City', 'Station.Code', 'Station.Location', 'Station.State', 'Data.Temperature.Avg Temp', 'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp', 'Data.Wind.Direction', 'Data.Wind.Speed']

# %% [markdown]
# # fix the column name if necessary
# df.columns=list of colomns
# pd.rename() can be used when changing name of coloumns or index

# %%
weather.columns=["precipitation","date","month","week","year","city","code","location","state","avg_temp",
"max_temp","min_temp","wind_dir","wind_speed"]

# %%
weather.head(3)
# Out:
#    precipitation       date  month  week  year        city code  \
# 0           0.00 2016-01-03      1     3  2016  Birmingham  BHM
# 1           0.00 2016-01-03      1     3  2016  Huntsville  HSV
# 2           0.16 2016-01-03      1     3  2016      Mobile  MOB
#
#          location    state  avg_temp  max_temp  min_temp  wind_dir  wind_speed
# 0  Birmingham, AL  Alabama        39        46        32        33        4.33
# 1  Huntsville, AL  Alabama        39        47        31        32        3.86
# 2      Mobile, AL  Alabama        46        51        41        35        9.73

# %% [markdown]
# # selecting rows and columns
# ->rows(slicing):
#
# "loc"  get us the data using named indexes
#
# "iloc" gets us the data using numeric indexes  when indexes are not set
#
# ->columns(dictionary style)
#
# "df(single)" requires name of coloumn  df=data frame
#
# "df(multiple)" requires a list of columns(multiple is list of named cols)

# %%
# single row:
print(weather.iloc[0])
# Out:
# precipitation                    0.0
# date             2016-01-03 00:00:00
# month                              1
# week                               3
# year                            2016
# city                      Birmingham
# code                             BHM
# location              Birmingham, AL
# state                        Alabama
# avg_temp                          39
# max_temp                          46
# min_temp                          32
# wind_dir                          33
# wind_speed                      4.33
# Name: 0, dtype: object

# %%
weather.iloc[-1]
# Out:
# precipitation                    0.1
# date             2017-01-01 00:00:00
# month                              1
# week                               1
# year                            2017
# city                        Sheridan
# code                             SHR
# location                Sheridan, WY
# state                        Wyoming
# avg_temp                          21
# max_temp                          34
# min_temp                           8
# wind_dir                          23
# wind_speed                      7.51
# Name: 16742, dtype: object

# %%
weather.iloc[:20]
# Out:
#     precipitation       date  month  week  year                      city  \
# 0            0.00 2016-01-03      1     3  2016                Birmingham
# 1            0.00 2016-01-03      1     3  2016                Huntsville
# 2            0.16 2016-01-03      1     3  2016                    Mobile
# 3            0.00 2016-01-03      1     3  2016                Montgomery
# 4            0.01 2016-01-03      1     3  2016                 Anchorage
# 5            0.09 2016-01-03      1     3  2016                   Annette
# 6            0.05 2016-01-03      1     3  2016                    Bethel
# 7            0.15 2016-01-03      1     3  2016                   Bettles
# 8            0.60 2016-01-03      1     3  2016                  Cold Bay
# 9            2.15 2016-01-03      1     3  2016                   Cordova
# 10           0.00 2016-01-03      1     3  2016  Delta Junction/Ft Greely
# 11           0.00 2016-01-03      1     3  2016                 Fairbanks
# ...

# %%
weather.iloc[20:25]
# Out:
#     precipitation       date  month  week  year      city code      location  \
# 20           0.10 2016-01-03      1     3  2016  Kotzebue  OTZ  Kotzebue, AK
# 21           0.01 2016-01-03      1     3  2016  Mc Grath  MCG  Mc Grath, AK
# 22           0.08 2016-01-03      1     3  2016      Nome  OME      Nome, AK
# 23           0.00 2016-01-03      1     3  2016  Northway  ORT  Northway, AK
# 24           0.40 2016-01-03      1     3  2016    Palmer  PAQ    Palmer, AK
#
#      state  avg_temp  max_temp  min_temp  wind_dir  wind_speed
# 20  Alaska        27        33        20        11       11.76
# 21  Alaska        30        39        20        15        3.70
# 22  Alaska        29        32        25         6       12.86
# 23  Alaska         0         8        -9        20        0.36
# 24  Alaska        37        42        32         8       10.50

# %%
# records 1 -15 with 5 colomns
weather.iloc[1:16,:5]
# Out:
#     precipitation       date  month  week  year
# 1            0.00 2016-01-03      1     3  2016
# 2            0.16 2016-01-03      1     3  2016
# 3            0.00 2016-01-03      1     3  2016
# 4            0.01 2016-01-03      1     3  2016
# 5            0.09 2016-01-03      1     3  2016
# 6            0.05 2016-01-03      1     3  2016
# 7            0.15 2016-01-03      1     3  2016
# 8            0.60 2016-01-03      1     3  2016
# 9            2.15 2016-01-03      1     3  2016
# 10           0.00 2016-01-03      1     3  2016
# 11           0.00 2016-01-03      1     3  2016
# 12           0.02 2016-01-03      1     3  2016
# 13           1.22 2016-01-03      1     3  2016
# 14           0.00 2016-01-03      1     3  2016
# 15           0.70 2016-01-03      1     3  2016

# %%
#last three col
weather.iloc[:15,11:14]
# Out:
#     min_temp  wind_dir  wind_speed
# 0         32        33        4.33
# 1         31        32        3.86
# 2         41        35        9.73
# 3         38        32        6.86
# 4         29        19        7.80
# 5         31         9        8.70
# 6         24         9       16.46
# 7          9         2        3.10
# 8         31        20        9.10
# 9         33         9        9.76
# 10        23        14       17.90
# 11         4         2        2.20
# 12        19        14        8.23
# 13        35         9       11.26
# 14        37         9       19.76

# %%
#col selection
weather["date"] # dictionary style
# Out:
# 0       2016-01-03
# 1       2016-01-03
# 2       2016-01-03
# 3       2016-01-03
# 4       2016-01-03
#            ...
# 16738   2017-01-01
# 16739   2017-01-01
# 16740   2017-01-01
# 16741   2017-01-01
# 16742   2017-01-01
# Name: date, Length: 16743, dtype: datetime64[ns]

# %%
weather["avg_temp"]
# Out:
# 0        39
# 1        39
# 2        46
# 3        45
# 4        34
#          ..
# 16738    23
# 16739    32
# 16740    17
# 16741    23
# 16742    21
# Name: avg_temp, Length: 16743, dtype: int64

# %%
weather.avg_temp # object style
# Out:
# 0        39
# 1        39
# 2        46
# 3        45
# 4        34
#          ..
# 16738    23
# 16739    32
# 16740    17
# 16741    23
# 16742    21
# Name: avg_temp, Length: 16743, dtype: int64

# %%
cols=["date","city","max_temp","min_temp"]
weather[cols]
# Out:
#             date        city  max_temp  min_temp
# 0     2016-01-03  Birmingham        46        32
# 1     2016-01-03  Huntsville        47        31
# 2     2016-01-03      Mobile        51        41
# 3     2016-01-03  Montgomery        52        38
# 4     2016-01-03   Anchorage        38        29
# ...          ...         ...       ...       ...
# 16738 2017-01-01      Casper        32        15
# 16739 2017-01-01    Cheyenne        42        21
# 16740 2017-01-01      Lander        29         4
# 16741 2017-01-01     Rawlins        31        13
# 16742 2017-01-01    Sheridan        34         8
#
# [16743 rows x 4 columns]

# %%
print(weather.columns.tolist())
# Out:
# ['precipitation', 'date', 'month', 'week', 'year', 'city', 'code', 'location', 'state', 'avg_temp', 'max_temp', 'min_temp', 'wind_dir', 'wind_speed']

# %%
weather[["date","city","max_temp","min_temp"]]
# Out:
#             date        city  max_temp  min_temp
# 0     2016-01-03  Birmingham        46        32
# 1     2016-01-03  Huntsville        47        31
# 2     2016-01-03      Mobile        51        41
# 3     2016-01-03  Montgomery        52        38
# 4     2016-01-03   Anchorage        38        29
# ...          ...         ...       ...       ...
# 16738 2017-01-01      Casper        32        15
# 16739 2017-01-01    Cheyenne        42        21
# 16740 2017-01-01      Lander        29         4
# 16741 2017-01-01     Rawlins        31        13
# 16742 2017-01-01    Sheridan        34         8
#
# [16743 rows x 4 columns]

# %%
# simple visualisation

weather["precipitation"].plot(figsize=(20,7),kind="hist",bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
weather["max_temp"].plot(figsize=(10,5),kind="kde")
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
weather[["max_temp","min_temp"]].plot(figsize=(20,6),
kind="hist",color=["green","yellow"],bins=25,alpha=.5,subplots=True,layout=(1,2))
# Out:
# array([[<AxesSubplot: ylabel='Frequency'>,
#         <AxesSubplot: ylabel='Frequency'>]], dtype=object)

# %%
weather[["max_temp","min_temp"]].plot(figsize=(20,6),
kind="hist",color=["green","yellow"],bins=25)
# Out:
# <AxesSubplot: ylabel='Frequency'>
